# %% [markdown]
# # Final Project Big Data Analytics

# %% [markdown]
# Disusun oleh Erfando Restu Agni

# %% [markdown]
# Dataset ini merupakan data winequality-white atau kualitas wine putih yang didalam data ini terdapat beberapa atribut yaitu:
#
# a. fixed accidity / asam campuran
#
# b. volatile acidity / keasaman yang mudah menguap
#
# c. citric acid / asam sitrat
#
# d. residual sugar / sisa gula
#
# e. chlorides / klorida
#
# f. free sulfur dioxide / sulfur dioksida bebas
#
# g. total sulfur sioxide / total sulfor dioksida
#
# h. density / massa jenis
#
# i. pH / tingkat keasaman
#
# j. sulphats / sulfat
#
# k. alcohol / alkohol
#
# l. quality / kualitas
#
# Dataset diperoleh dari   di <a href="https://archive.ics.uci.edu/ml/index.php">UCI Machine Learning</a>
#
#
# Pertama yang dilakukan adalah meload data dari file data set winequality-white(1).csv"

# %%
import pandas as pd
namaFilefo = "G:\\winequality-white(1).csv"
data = pd.read_csv(namaFilefo)
data
# Out:
#       fixed acidity volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.27         0.36            20.7      0.045
# 1               6.3              0.3         0.34             1.6      0.049
# 2               8.1             0.28         0.40             6.9      0.050
# 3               7.2             0.23         0.32             8.5      0.058
# 4               7.2             0.23         0.32             8.5      0.058
# ...             ...              ...          ...             ...        ...
# 4893            6.2             0.21         0.29             1.6      0.039
# 4894            6.6             0.32         0.36             8.0      0.047
# 4895            6.5             0.24         0.19             1.2      0.041
# 4896            5.5             0.29         0.30             1.1      0.022
# 4897            6.0             0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# # Melihat features yang terdapat dalam dataset

# %%
# Melihat features yang terdapat dalam dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null object
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null object
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null object
# quality                 4898 non-null int64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 459.3+ KB

# %% [markdown]
# # Scatter Plot

# %%
# Melihat nilai korelasi antar features satu dengan features lainnya
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot=True, linewidths=0.05, fmt = '.2f', cmap="magma")
plt.show()

# %%
# Operasi basic
import numpy as np
import pandas as pd

# Visualisasi
import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(data)
plt.show()

# %% [markdown]
# Dari scatter plot diatas dipilih 2 atribut yang memiliki dugaan terdapat korelasi, dan yang saya pilih yaitu atribut total sulfur dioxide dan free sulfur dioxide, dikarenakan dari gambar bentuk scatter plot memiliki kecenderungan hubungan positif yaitu bernilai 0.62 .
#
# Untuk scatter plot antara total sulfur dioxide dan free sulfur dioxide yang lebih jelasnya yaitu seperti berikut

# %%
import matplotlib.pyplot as plt
plt.scatter(data['free sulfur dioxide'], data['total sulfur dioxide'])
plt.show()

# %% [markdown]
# # Statistik Deskriptif

# %% [markdown]
# Selanjutnya dilakukan statistik deskriptif dengan mencari mean, median, standar deviasi, nilai minimal, dan nilai maksimal untuk masing-masing data.

# %%
data.describe()
# Out:
#        fixed acidity  citric acid  residual sugar    chlorides  \
# count    4898.000000  4898.000000     4898.000000  4898.000000
# mean        6.854788     0.334192        6.391415     0.045772
# std         0.843868     0.121020        5.072058     0.021848
# min         3.800000     0.000000        0.600000     0.009000
# 25%         6.300000     0.270000        1.700000     0.036000
# 50%         6.800000     0.320000        5.200000     0.043000
# 75%         7.300000     0.390000        9.900000     0.050000
# max        14.200000     1.660000       65.800000     0.346000
#
#        free sulfur dioxide  total sulfur dioxide           pH    sulphates  \
# count          4898.000000           4898.000000  4898.000000  4898.000000
# mean             35.308085            138.360657     3.188267     0.489847
# std              17.007137             42.498065     0.151001     0.114126
# min               2.000000              9.000000     2.720000     0.220000
# ...

# %% [markdown]
# Statistik dekriptif diatas untuk mengetahui jumlah data, nilai rata-rata, standar deviasi, nilai minimal, nilai quantil, median, dan nilai maximal untuk semua variabel.

# %% [markdown]
# Dilakukan analisis model regresi dengan menggunakan regresi linear antara free sulfur dioxide dan total sulfur dioxide.

# %% [markdown]
# # Regresi Linear

# %% [markdown]
# Selanjutnya mengunakan regresi linear untuk menghitung mean absolute error, mean squared error, r2

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


# script untuk generate data dummy
# variabel view (independen)
# variabel sold (dependen)

x = np.array(data["free sulfur dioxide"])
y = np.array(data["total sulfur dioxide"])


print(x)
print(y)


# menampilkan data dengan scatter plot
plt.scatter(x, y)
plt.title("free sulfur dioxide vs total sulfur dioxide")
plt.xlabel("free sulfur dioxide")
plt.ylabel("total sulfur dioxide")
plt.show()
# Out:
# [45. 14. 30. ... 30. 20. 22.]
# [170. 132.  97. ... 111. 110.  98.]

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
def estimate_coef(x, y): 
    # number of observations/points 
    n = np.size(x) 
  
    # mean of x and y vector 
    m_x, m_y = np.mean(x), np.mean(y) 
  
    # calculating cross-deviation and deviation about x 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 
  
    # calculating regression coefficients 
    b_1 = SS_xy / SS_xx 
    b_0 = m_y - b_1*m_x 
  
    return(b_0, b_1) 
  
def plot_regression_line(x, y, b): 
    # plotting the actual points as scatter plot 
    plt.scatter(x, y, color = "m", 
               marker = "o", s = 30) 
  
    # predicted response vector 
    y_pred = b[0] + b[1]*x 
  
    # plotting the regression line 
    plt.plot(x, y_pred, color = "g") 
  
    # putting labels 
    plt.xlabel('x') 
    plt.ylabel('y') 
  
    # function to show plot 
    plt.show() 
  
def main(): 
    # observations 
    x = np.array(data["free sulfur dioxide"])
    y = np.array(data["total sulfur dioxide"])

  
    # estimating coefficients 
    b = estimate_coef(x, y) 
    print("Estimated coefficients:\nb_0 = {} \
    \nb_1 = {}".format(b[0], b[1])) 
  
    # plotting regression line 
    plot_regression_line(x, y, b) 
  
if __name__ == "__main__": 
    main()
# Out:
# Estimated coefficients:
# b_0 = 84.05553034968443
# b_1 = 1.5380366045093685

# %% [markdown]
# sehingga nilai regresi linearnya adalah y = 84.05553034968443 + 1.5380366045093685x
#
# selanjutnya akan dilihat nilai residunya

# %%
#multiple regression
import matplotlib.pyplot as plt 
import numpy as np 
from sklearn import datasets, linear_model, metrics 
  
# load the boston dataset 
boston = datasets.load_boston(return_X_y=False) 
  
# defining feature matrix(X) and response vector(y) 
X = boston.data 
y = boston.target 
  
# splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, 
                                                    random_state=1) 
  
# create linear regression object 
reg = linear_model.LinearRegression() 
  
# train the model using the training sets 
reg.fit(X_train, y_train) 
  
# regression coefficients 
print('Coefficients: \n', reg.coef_) 
  
# variance score: 1 means perfect prediction 
print('Variance score: {}'.format(reg.score(X_test, y_test))) 
  
# plot for residual error 
  
## setting plot style 
plt.style.use('fivethirtyeight') 
  
## plotting residual errors in training data 
plt.scatter(reg.predict(X_train), reg.predict(X_train) - y_train, 
            color = "green", s = 10, label = 'Train data') 
  
## plotting residual errors in test data 
plt.scatter(reg.predict(X_test), reg.predict(X_test) - y_test, 
            color = "blue", s = 10, label = 'Test data') 
  
## plotting line for zero residual error 
plt.hlines(y = 0, xmin = 0, xmax = 50, linewidth = 2) 
  
## plotting legend 
plt.legend(loc = 'upper right') 
  
## plot title 
plt.title("Residual errors") 
  
## function to show plot 
plt.show()
# Out:
# Coefficients:
#  [-8.95714048e-02  6.73132853e-02  5.04649248e-02  2.18579583e+00
#  -1.72053975e+01  3.63606995e+00  2.05579939e-03 -1.36602886e+00
#   2.89576718e-01 -1.22700072e-02 -8.34881849e-01  9.40360790e-03
#  -5.04008320e-01]
# Variance score: 0.7209056672661746

# %% [markdown]
# terdapat residual errors pada train data dan test data.

# %%
from sklearn.linear_model import LinearRegression


# instansiasi model linear regression
# dengan menggunakan default parameter
linreg = LinearRegression()


# menghitung nilai optimum vektor w
# dengan metode ordinary least squares
# seperti yang telah kita bahas di atas
# .reshape(-1, 1) transform 1D array ke 2D array
# jumlah baris x 1 kolom
x = np.array(data["free sulfur dioxide"])
y1 = np.array(data["total sulfur dioxide"])


# menghitung hasil prediksi



# menampilkan hasil prediksi
plt.scatter(x, y1)
plt.title("free sulfur dioxide vs total sulfur dioxide")
plt.xlabel("free sulfur dioxide")
plt.ylabel("total sulfur dioxide")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-dc9503cc5c08> in <module>
#       1 # untuk menampilkan model yang dihasilkan
#       2 # nilai optimum vektor w
# ----> 3 print("Koefisien w_1 ...:", linreg.coef_)
#       4 print("Intercept (w_0):", linreg.intercept_)
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-f9e64d02ff30> in <module>
#       1 # untuk menghitung squared error
# ----> 2 np.square(y - "total sulfur dioxide").sum()
#
# TypeError: ufunc 'subtract' did not contain a loop with signature matching types dtype('<U32') dtype('<U32') dtype('<U32')

# %%
# Fungsi Sigmoid
def sigmoid(x, Beta_1, Beta_2):
    y = 1 / (1 + np.exp(-Beta_1*(x-Beta_2)))
    return y

# Fungsi Eksponensial
def expo(x,Beta_0, Beta_1):
    y = Beta_0*np.exp(Beta_1*x)
    return y

# Fungsi Kubik
def qubic(x,Beta_0,Beta_1,Beta_2,Beta_3):
    y = Beta_0+Beta_1*x+Beta_2*x**2+Beta_3*x**3
    return y

# Fungsi Kuadratik
def quad(x,Beta_0,Beta_1,Beta_2):
    y = Beta_0+Beta_1*x+Beta_2*x**2
    return y

# %%
from scipy.optimize import curve_fit
import numpy as np

func = ['Sigmoid','Eksponensial','Kubik','Kuadratik']

for i in range(len(func)):
    # Membangun model
    if(i == 0):
        # Membangun model dengan data train
        popt, pcov = curve_fit(sigmoid, train_x.flatten(), train_y.flatten(), maxfev=100000) 
        y_hat = sigmoid(test_x, *popt) # Memprediksi dengan test set
    if(i == 1):
        # Membangun model dengan data train
        popt, pcov = curve_fit(expo, train_x.flatten(), train_y.flatten(),maxfev=100000)
        y_hat = expo(test_x, *popt) # Memprediksi dengan test set
    if(i == 2):
        # Membangun model dengan data train
        popt, pcov = curve_fit(qubic, train_x.flatten(), train_y.flatten(), maxfev=100000) 
        y_hat = qubic(test_x, *popt) # Memprediksi dengan test set
    if(i == 3):
        # Membangun model dengan data train
        popt, pcov = curve_fit(quad, train_x.flatten(), train_y.flatten(), maxfev=100000) 
        y_hat = quad(test_x, *popt) # Memprediksi dengan test set  
    
    mae = np.mean(np.absolute(y_hat - test_y)) # Menghitung Mean Absolute Error
    mse = np.mean((y_hat - test_y) ** 2) # Menghitung Mean Square Error
    r2  = r2_score(y_hat , test_y) # Menghitung R2
    rmse = math.sqrt(mse)

    # Evaluasi
    print("\n{}".format(func[i]))
    print("MAE using {} Function: {:0.2E} ".format(func[i],mae))
    print("MSE using {} Function: {:0.2E}".format(func[i],mse))
    print("RMSE using {} Function: {:0.2E}".format(func[i],rmse))
    print("R2-score using {} Function: {:0.2E}".format(func[i],r2))
    
    result[func[i]] = [mae,mse,rmse,r2] # Menyimpan hasil

result.rename(index={0:'MAE',1:'MSE', 2:'RMSE',3:'R2'}, inplace=True)
print('\n')
display(result)
# Out:
# Sigmoid
# MAE using Sigmoid Function: 3.48E-02
# MSE using Sigmoid Function: 2.06E-03
# RMSE using Sigmoid Function: 4.53E-02
# R2-score using Sigmoid Function: -6.32E-01
#
# Eksponensial
# MAE using Eksponensial Function: 3.50E-02
# MSE using Eksponensial Function: 2.09E-03
# RMSE using Eksponensial Function: 4.57E-02
# R2-score using Eksponensial Function: -6.90E-01
#
# Kubik
# MAE using Kubik Function: 3.39E-02
# MSE using Kubik Function: 2.00E-03
# RMSE using Kubik Function: 4.47E-02
# R2-score using Kubik Function: -5.28E-01
#
# Kuadratik
# MAE using Kuadratik Function: 3.41E-02
# MSE using Kuadratik Function: 1.98E-03
# RMSE using Kuadratik Function: 4.45E-02
# R2-score using Kuadratik Function: -4.84E-01
#         Linear   Sigmoid  Eksponensial     Kubik  Kuadratik
# MAE   0.033859  0.034832      0.035047  0.033948   0.034119
# MSE   0.001961  0.002055      0.002093  0.001999   0.001983
# RMSE  0.044281  0.045337      0.045749  0.044705   0.044527
# ...

# %% [markdown]
# Menampilkan diagram korelasi antara free sulfur dioxide dan total sulfur dioxide dengan regresi linear

# %%
def linear(x, Beta_0, Beta_1):
    y = Beta_0 + Beta_1*x
    return y

popt1, pcov1 = curve_fit(linear, train_x.flatten(), train_y.flatten())
y = linear(xdata, *popt1)
plt.scatter(xdata, ydata,marker = '+',label = "Data")
plt.scatter(xdata,y, marker = '*',label = "Linear")

plt.legend(loc='best')
plt.ylabel('total sulfur dioxide')
plt.xlabel('free sulfur dioxide')
plt.title("Korelasi antara total sulfur dioxide dan free sulfur dioxide")
plt.show()

# %% [markdown]
# Terhadap dataset yang diperoleh, kemuadian dilakukan analisis menggunakan clustering

# %% [markdown]
# # Clustering

# %% [markdown]
# Anaslis clustering yang digunakan disini adalah KMeans Clustering

# %%
import random 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs 
# %matplotlib inline

# %%
df = data[['free sulfur dioxide','total sulfur dioxide']]
df.head()
# Out:
#    free sulfur dioxide  total sulfur dioxide
# 0                 45.0                 170.0
# 1                 14.0                 132.0
# 2                 30.0                  97.0
# 3                 47.0                 186.0
# 4                 47.0                 186.0

# %%
# Mengambil Nilai and memplotkan
f1 = data['free sulfur dioxide'].values
f2 = data['total sulfur dioxide'].values
X = np.array(list(zip(f1, f2)))
plt.scatter(f1, f2, c='black', s=7)

# %%
#  Jarak Euclid
def dist(a, b, ax=1):
    return np.linalg.norm(a - b, axis=ax)

# %%
# Nomor Kluster
k = 3
# Koordinat X dari random centroids
C_x = np.random.randint(0, np.max(X)-20, size=k)
# Koordinat Y dari random centroids
C_y = np.random.randint(0, np.max(X)-20, size=k)
C = np.array(list(zip(C_x, C_y)), dtype=np.float32)
print(C)
# Out:
# [[172. 192.]
#  [ 47. 323.]
#  [117. 251.]]

# %%
# Plotting dengan Centroids
plt.scatter(f1, f2, c='#050505', s=7)
plt.scatter(C_x, C_y, marker='*', s=200, c='g')

# %%
np.random.seed(0)

# %%
from sklearn.preprocessing import StandardScaler
X = data.values[:,1:]
X = np.nan_to_num(X)
Clus_dataSet = StandardScaler(X).fit_transform(X)
Clus_dataSet
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-4731096cd461> in <module>
#       2 X = data.values[:,1:]
#       3 X = np.nan_to_num(X)
# ----> 4 Clus_dataSet = StandardScaler(X).fit_transform(X)
#       5 Clus_dataSet
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     462         if y is None:
#     463             # fit method of arity 1 (unsupervised transformation)
# --> 464             return self.fit(X, **fit_params).transform(X)
#     465         else:
#     466             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     643         # Reset internal state before fitting
#     644         self._reset()
# --> 645         return self.partial_fit(X, y)
#     646
#     647     def partial_fit(self, X, y=None):
#
# ...

# %% [markdown]
# # Pemodelan K-Means pada Dataset

# %%
# memilih kolom untuk klasterisasi dengan k-means
selected_cols = ["free sulfur dioxide","total sulfur dioxide","sulphates"]
cluster_data = data.loc[:,selected_cols]

# %%
def distributions(df):
    fig, (ax1, ax2, ax3) = plt.subplots(3,1, figsize=(8,8))
    sns.distplot(df["free sulfur dioxide"], ax=ax1)
    sns.distplot(df["total sulfur dioxide"], ax=ax2)
    sns.distplot(df["sulphates"], ax=ax3)
    plt.tight_layout()

# %%
distributions(cluster_data)

# %% [markdown]
# Dari hasil diatas didapatkan distribusi yang cenderung miring ke arah kanan, kemiringan tersebut akan dihilangkan dengan transformasi logaritmik untuk hasil yang lebih baik, Berikut adalah transformasi logistik

# %%
cluster_log = np.log(cluster_data)
distributions(cluster_log)

# %% [markdown]
# Terlihat dari gambar di atas bahwa kemiringan telah dihilangkan,
# langkah selanjutnya adalah centering dan scaling variabel, hal ini akan memerlukan algoritma KMeans.

# %%
scaler = StandardScaler()
cluster_scaled = scaler.fit_transform(cluster_log)
